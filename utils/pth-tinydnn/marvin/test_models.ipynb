# %%
#@title Training parameters
model_name = "JNN19" #@param {type:"string"}

# %% [markdown]
# # Colab setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Environment setup

# %%
import os
if not os.path.exists('/content/drive/My Drive/rUNSWift'):
  raise FileNotFoundError('Please add https://drive.google.com/drive/folders/1OU4Bg0qz_DnF7DxjOFTlFc9r5hHGUrFD?usp=sharing to "My Drive"')
os.chdir('/content/drive/My Drive/rUNSWift/Vision/DNN 2020/marvin training model')

# !pip install thop
# !sed -i 's/#  print/print/;/print(prefix/s/.item()//g;' /usr/local/lib/python3.6/dist-packages/thop/profile.py
# Out:
# Collecting thop
#   Downloading https://files.pythonhosted.org/packages/6c/8b/22ce44e1c71558161a8bd54471123cc796589c7ebbfc15a7e8932e522f83/thop-0.0.31.post2005241907-py3-none-any.whl
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from thop) (1.5.0+cu101)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.0.0->thop) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch>=1.0.0->thop) (1.18.5)
# Installing collected packages: thop
# Successfully installed thop-0.0.31.post2005241907

# %% [markdown]
# # Training model
# ___
# The neural network outputs an image with the same size as the input image. Each pixel in the output is either a 0 or a 1 where a 1 indicates that the pixel belongs to a robot.  The bounding boxes are then drawn in postprocessing.
#
# We tested multiple models with different architectures (skip connections, depthwise-separable convolutions, inverted residual bottlenecks, etc.) but many of then could not be converted to `tiny-dnn` because of the limited types of layers available in `tiny-dnn`. Also, when we tested models on the robot they proved to be far too slow so we had to cut down the number of layers and adjust the network parameters to improve inference time.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchsummary import summary
from thop import profile

import basic_models
from dataloaderV2 import RobotAEDataset
from utils import *

# %%
if 'COLAB_TPU_ADDR' in os.environ:
  VERSION = "1.5" # from https://colab.research.google.com/github/pytorch/xla/blob/master/contrib/colab/getting-started.ipynb#scrollTo=sPJVqAKyml5W&line=1&uniqifier=1
  # !curl https://raw.githubusercontent.com/pytorch/xla/master/contrib/scripts/env-setup.py -o pytorch-xla-env-setup.py
  # !python pytorch-xla-env-setup.py --version $VERSION
  import torch_xla
  import torch_xla.core.xla_model as xm
  device = xm.xla_device()
elif torch.cuda.is_available():
  device = torch.device("cuda")
else:
  device = torch.device("cpu")
device
# Out:
# device(type='cpu')

# %%
# Load dataset (assumes the labelled data already exists)
val_path = '../data/validation'
train_path = '../data/training'
val_dataset = RobotAEDataset(val_path, downsample_factor=0.25, device=device)
print('val_dataset   loaded')
train_dataset = RobotAEDataset(train_path, downsample_factor=0.25, device=device)
print('train_dataset loaded')
# Out:
# val_dataset   loaded
# train_dataset loaded

# %%
# Create dataset loaders
trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=0)
valloader = torch.utils.data.DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=0)

# %%
# Loss function & optimizer
pos_weight = torch.Tensor([1], device=device) # hyperparameter (> 1 means more weight to false negatives, < 1 means more weight to false positives)
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

# %%
# [Re]load model
from importlib import reload  # Py3 only; unneeded in py2.
basic_models = reload(basic_models)
model = getattr(basic_models, model_name)()

# Print model info
flops, params = count_params(model, torch.randn(1, 1, 240, 320))

# Model
model = model.to(device)
summary(model, (1, 240, 320))

# Save path for model
model_path = f'./models/{model_name}.pth'

# Optimizer
optimizer = optim.Adam(model.parameters(), lr=1e-3)
# Out:
# 				 Sequential (1843200.0, 80.0)
# 			 conv_bn_relu (1843200.0, 80.0)
# 				 Sequential (7488000.0, 3088.0)
# 			 conv_bn_relu (7488000.0, 3088.0)
# 				 Sequential (7488000.0, 3088.0)
# 			 conv_bn_relu (7488000.0, 3088.0)
# 				 Sequential (5616000.0, 4632.0)
# 			 conv_bn_relu (5616000.0, 4632.0)
# 				 Sequential (8380800.0, 6936.0)
# 			 conv_bn_relu (8380800.0, 6936.0)
# 				 Sequential (2793600.0, 9248.0)
# 			 conv_bn_relu (2793600.0, 9248.0)
# 				 Sequential (3715200.0, 12320.0)
# 			 conv_bn_relu (3715200.0, 12320.0)
# 				 Sequential (3715200.0, 12320.0)
# 			 conv_bn_relu (3715200.0, 12320.0)
# 		 Sequential (42000300.0, 52097.0)
# 	 JNN19 (42000300.0, 52097.0)
# params:	52,097
# flops:	42.000M
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 8, 120, 160]              80
#        BatchNorm2d-2          [-1, 8, 120, 160]               0
#               ReLU-3          [-1, 8, 120, 160]               0
#       conv_bn_relu-4          [-1, 8, 120, 160]               0
#             Conv2d-5           [-1, 16, 60, 40]           3,088
#        BatchNorm2d-6           [-1, 16, 60, 40]               0
#               ReLU-7           [-1, 16, 60, 40]               0
#       conv_bn_relu-8           [-1, 16, 60, 40]               0
#          ZeroPad2d-9           [-1, 16, 60, 41]               0
#            Conv2d-10           [-1, 16, 60, 40]           3,088
#       BatchNorm2d-11           [-1, 16, 60, 40]               0
#              ReLU-12           [-1, 16, 60, 40]               0
#      conv_bn_relu-13           [-1, 16, 60, 40]               0
#         ZeroPad2d-14           [-1, 16, 60, 41]               0
#            Conv2d-15           [-1, 24, 30, 40]           4,632
#       BatchNorm2d-16           [-1, 24, 30, 40]               0
#              ReLU-17           [-1, 24, 30, 40]               0
#      conv_bn_relu-18           [-1, 24, 30, 40]               0
#         ZeroPad2d-19           [-1, 24, 30, 41]               0
#            Conv2d-20           [-1, 24, 30, 40]           6,936
#       BatchNorm2d-21           [-1, 24, 30, 40]               0
#              ReLU-22           [-1, 24, 30, 40]               0
#      conv_bn_relu-23           [-1, 24, 30, 40]               0
#            Conv2d-24           [-1, 32, 15, 20]           9,248
#       BatchNorm2d-25           [-1, 32, 15, 20]               0
#              ReLU-26           [-1, 32, 15, 20]               0
#      conv_bn_relu-27           [-1, 32, 15, 20]               0
#         ZeroPad2d-28           [-1, 32, 15, 21]               0
#            Conv2d-29           [-1, 32, 15, 20]          12,320
#       BatchNorm2d-30           [-1, 32, 15, 20]               0
#              ReLU-31           [-1, 32, 15, 20]               0
#      conv_bn_relu-32           [-1, 32, 15, 20]               0
#         ZeroPad2d-33           [-1, 32, 15, 21]               0
#            Conv2d-34           [-1, 32, 15, 20]          12,320
#       BatchNorm2d-35           [-1, 32, 15, 20]               0
#              ReLU-36           [-1, 32, 15, 20]               0
#      conv_bn_relu-37           [-1, 32, 15, 20]               0
#         ZeroPad2d-38           [-1, 32, 15, 21]               0
#            Conv2d-39            [-1, 1, 15, 20]             385
#          Upsample-40          [-1, 1, 240, 320]               0
# ================================================================
# Total params: 52,097
# Trainable params: 52,097
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.29
# Forward/backward pass size (MB): 11.31
# Params size (MB): 0.20
# Estimated Total Size (MB): 11.80
# ----------------------------------------------------------------

# %%
# Train model
num_epochs = 200
best_loss = 9999999999

for epoch in range(num_epochs):
    train_loss = train(model, device, trainloader, criterion, optimizer, epoch)
    val_loss, _ = evaluate(model, device, valloader, criterion)
    if val_loss < best_loss:
            best_loss = val_loss
            torch.save(model.state_dict(), model_path)
# Out:
# Epoch 1
# Training loss: 0.00846
# Validation loss: 0.01048
# Average inference time: 4.777 ms
# Epoch 2
# Training loss: 0.00313
# Validation loss: 0.01141
# Average inference time: 4.775 ms
# Epoch 3
# Training loss: 0.00218
# Validation loss: 0.00334
# Average inference time: 4.596 ms
# Epoch 4
# Training loss: 0.00174
# Validation loss: 0.00749
# Average inference time: 5.020 ms
# Epoch 5
# Training loss: 0.00165
# Validation loss: 0.00542
# Average inference time: 4.843 ms
# Epoch 6
# Training loss: 0.00148
# Validation loss: 0.00224
# Average inference time: 4.913 ms
# Epoch 7
# Training loss: 0.00113
# Validation loss: 0.00296
# Average inference time: 4.870 ms
# Epoch 8
# Training loss: 0.00103
# Validation loss: 0.00270
# Average inference time: 4.575 ms
# Epoch 9
# Training loss: 0.00090
# Validation loss: 0.00163
# Average inference time: 4.808 ms
# Epoch 10
# Training loss: 0.00089
# Validation loss: 0.00394
# Average inference time: 4.602 ms
# Epoch 11
# Training loss: 0.00076
# Validation loss: 0.00152
# Average inference time: 4.842 ms
# Epoch 12
# Training loss: 0.00084
# Validation loss: 0.00183
# Average inference time: 4.708 ms
# Epoch 13
# Training loss: 0.00071
# Validation loss: 0.00253
# Average inference time: 4.881 ms
# Epoch 14
# Training loss: 0.00079
# Validation loss: 0.00140
# Average inference time: 4.968 ms
# Epoch 15
# Training loss: 0.00077
# Validation loss: 0.00917
# Average inference time: 4.823 ms
# Epoch 16
# Training loss: 0.00068
# Validation loss: 0.00108
# Average inference time: 4.860 ms
# Epoch 17
# Training loss: 0.00064
# Validation loss: 0.00279
# Average inference time: 4.888 ms
# Epoch 18
# Training loss: 0.00065
# Validation loss: 0.00286
# Average inference time: 4.982 ms
# Epoch 19
# Training loss: 0.00062
# Validation loss: 0.00249
# Average inference time: 4.829 ms
# Epoch 20
# Training loss: 0.00057
# Validation loss: 0.00109
# Average inference time: 4.899 ms
# Epoch 21
# Training loss: 0.00062
# Validation loss: 0.00173
# Average inference time: 4.685 ms
# Epoch 22
# Training loss: 0.00067
# Validation loss: 0.00367
# Average inference time: 4.821 ms
# Epoch 23
# Training loss: 0.00055
# Validation loss: 0.00166
# Average inference time: 4.792 ms
# Epoch 24
# Training loss: 0.00118
# Validation loss: 0.00138
# Average inference time: 4.672 ms
# Epoch 25
# Training loss: 0.00066
# Validation loss: 0.00875
# Average inference time: 4.760 ms
# Epoch 26
# Training loss: 0.00064
# Validation loss: 0.00136
# Average inference time: 4.893 ms
# Epoch 27
# Training loss: 0.00052
# Validation loss: 0.00113
# Average inference time: 4.807 ms
# Epoch 28
# Training loss: 0.00055
# Validation loss: 0.00107
# Average inference time: 4.828 ms
# Epoch 29
# Training loss: 0.00045
# Validation loss: 0.00130
# Average inference time: 4.800 ms
# Epoch 30
# Training loss: 0.00041
# Validation loss: 0.00134
# Average inference time: 4.789 ms
# Epoch 31
# Training loss: 0.00048
# Validation loss: 0.00117
# Average inference time: 4.842 ms
# Epoch 32
# Training loss: 0.00080
# Validation loss: 0.00169
# Average inference time: 5.034 ms
# Epoch 33
# Training loss: 0.00049
# Validation loss: 0.00146
# Average inference time: 4.823 ms
# Epoch 34
# Training loss: 0.00042
# Validation loss: 0.00125
# Average inference time: 4.798 ms
# Epoch 35
# Training loss: 0.00038
# Validation loss: 0.00162
# Average inference time: 4.755 ms
# Epoch 36
# Training loss: 0.00041
# Validation loss: 0.00095
# Average inference time: 4.795 ms
# Epoch 37
# Training loss: 0.00038
# Validation loss: 0.00130
# Average inference time: 4.896 ms
# Epoch 38
# Training loss: 0.00035
# Validation loss: 0.00091
# Average inference time: 5.033 ms
# Epoch 39
# Training loss: 0.00035
# Validation loss: 0.00125
# Average inference time: 5.161 ms
# Epoch 40
# Training loss: 0.00037
# Validation loss: 0.00110
# Average inference time: 4.705 ms
# Epoch 41
# Training loss: 0.00034
# Validation loss: 0.00129
# Average inference time: 4.775 ms
# Epoch 42
# Training loss: 0.00033
# Validation loss: 0.00148
# Average inference time: 4.779 ms
# Epoch 43
# Training loss: 0.00032
# Validation loss: 0.00197
# Average inference time: 4.846 ms
# Epoch 44
# Training loss: 0.00031
# Validation loss: 0.00167
# Average inference time: 4.625 ms
# Epoch 45
# Training loss: 0.00028
# Validation loss: 0.00125
# Average inference time: 5.035 ms
# Epoch 46
# Training loss: 0.00027
# Validation loss: 0.00117
# Average inference time: 4.988 ms
# Epoch 47
# Training loss: 0.00026
# Validation loss: 0.00117
# Average inference time: 4.730 ms
# Epoch 48
# Training loss: 0.00027
# Validation loss: 0.00140
# Average inference time: 4.671 ms
# Epoch 49
# Training loss: 0.00026
# Validation loss: 0.00164
# Average inference time: 4.809 ms
# Epoch 50
# Training loss: 0.00025
# Validation loss: 0.00102
# Average inference time: 4.838 ms
# Epoch 51
# Training loss: 0.00025
# Validation loss: 0.00117
# Average inference time: 4.792 ms
# Epoch 52
# Training loss: 0.00024
# Validation loss: 0.00109
# Average inference time: 4.712 ms
# Epoch 53
# Training loss: 0.00023
# Validation loss: 0.00106
# Average inference time: 4.839 ms
# Epoch 54
# Training loss: 0.00023
# Validation loss: 0.00107
# Average inference time: 4.854 ms
# Epoch 55
# Training loss: 0.00024
# Validation loss: 0.00117
# Average inference time: 4.725 ms
# Epoch 56
# Training loss: 0.00026
# Validation loss: 0.00215
# Average inference time: 4.787 ms
# Epoch 57
# Training loss: 0.00025
# Validation loss: 0.00113
# Average inference time: 4.794 ms
# Epoch 58
# Training loss: 0.00027
# Validation loss: 0.00681
# Average inference time: 4.938 ms
# Epoch 59
# Training loss: 0.00091
# Validation loss: 0.00180
# Average inference time: 5.107 ms
# Epoch 60
# Training loss: 0.00076
# Validation loss: 0.00114
# Average inference time: 5.104 ms
# Epoch 61
# Training loss: 0.00044
# Validation loss: 0.00125
# Average inference time: 4.691 ms
# Epoch 62
# Training loss: 0.00030
# Validation loss: 0.00121
# Average inference time: 4.945 ms
# Epoch 63
# Training loss: 0.00029
# Validation loss: 0.00102
# Average inference time: 4.799 ms
# Epoch 64
# Training loss: 0.00031
# Validation loss: 0.00122
# Average inference time: 4.711 ms
# Epoch 65
# Training loss: 0.00029
# Validation loss: 0.00193
# Average inference time: 4.901 ms
# Epoch 66
# Training loss: 0.00026
# Validation loss: 0.00119
# Average inference time: 5.002 ms
# Epoch 67
# Training loss: 0.00023
# Validation loss: 0.00134
# Average inference time: 4.688 ms
# Epoch 68
# Training loss: 0.00022
# Validation loss: 0.00111
# Average inference time: 5.107 ms
# Epoch 69
# Training loss: 0.00021
# Validation loss: 0.00119
# Average inference time: 4.661 ms
# Epoch 70
# Training loss: 0.00022
# Validation loss: 0.00113
# Average inference time: 4.978 ms
# Epoch 71
# Training loss: 0.00037
# Validation loss: 0.00213
# Average inference time: 5.067 ms
# Epoch 72
# Training loss: 0.00085
# Validation loss: 0.00114
# Average inference time: 4.766 ms
# Epoch 73
# Training loss: 0.00046
# Validation loss: 0.00123
# Average inference time: 4.715 ms
# Epoch 74
# Training loss: 0.00035
# Validation loss: 0.00123
# Average inference time: 4.648 ms
# Epoch 75
# Training loss: 0.00029
# Validation loss: 0.00102
# Average inference time: 4.746 ms
# Epoch 76
# Training loss: 0.00024
# Validation loss: 0.00112
# Average inference time: 5.018 ms
# Epoch 77
# Training loss: 0.00023
# Validation loss: 0.00099
# Average inference time: 4.965 ms
# Epoch 78
# Training loss: 0.00023
# Validation loss: 0.00138
# Average inference time: 4.783 ms
# Epoch 79
# Training loss: 0.00039
# Validation loss: 0.00115
# Average inference time: 4.827 ms
# Epoch 80
# Training loss: 0.00049
# Validation loss: 0.00130
# Average inference time: 4.706 ms
# Epoch 81
# Training loss: 0.00028
# Validation loss: 0.00106
# Average inference time: 4.682 ms
# Epoch 82
# Training loss: 0.00023
# Validation loss: 0.00114
# Average inference time: 5.051 ms
# Epoch 83
# Training loss: 0.00021
# Validation loss: 0.00117
# Average inference time: 4.970 ms
# Epoch 84
# Training loss: 0.00032
# Validation loss: 0.04035
# Average inference time: 5.028 ms
# Epoch 85
# Training loss: 0.00035
# Validation loss: 0.00115
# Average inference time: 4.878 ms
# Epoch 86
# Training loss: 0.00023
# Validation loss: 0.00133
# Average inference time: 4.826 ms
# Epoch 87
# Training loss: 0.00020
# Validation loss: 0.00126
# Average inference time: 5.365 ms
# Epoch 88
# Training loss: 0.00020
# Validation loss: 0.00105
# Average inference time: 4.734 ms
# Epoch 89
# Training loss: 0.00019
# Validation loss: 0.00106
# Average inference time: 4.911 ms
# Epoch 90
# Training loss: 0.00019
# Validation loss: 0.00114
# Average inference time: 5.052 ms
# Epoch 91
# Training loss: 0.00019
# Validation loss: 0.00115
# Average inference time: 5.176 ms
# Epoch 92
# Training loss: 0.00036
# Validation loss: 0.00222
# Average inference time: 4.789 ms
# Epoch 93
# Training loss: 0.00022
# Validation loss: 0.00135
# Average inference time: 4.721 ms
# Epoch 94
# Training loss: 0.00020
# Validation loss: 0.00135
# Average inference time: 4.730 ms
# Epoch 95
# Training loss: 0.00020
# Validation loss: 0.00148
# Average inference time: 4.747 ms
# Epoch 96
# Training loss: 0.00018
# Validation loss: 0.00148
# Average inference time: 4.922 ms
# Epoch 97
# Training loss: 0.00018
# Validation loss: 0.00120
# Average inference time: 4.823 ms
# Epoch 98
# Training loss: 0.00018
# Validation loss: 0.00171
# Average inference time: 4.845 ms
# Epoch 99
# Training loss: 0.00017
# Validation loss: 0.00146
# Average inference time: 4.791 ms
# Epoch 100
# Training loss: 0.00016
# Validation loss: 0.00132
# Average inference time: 5.008 ms
# Epoch 101
# Training loss: 0.00027
# Validation loss: 0.00153
# Average inference time: 4.781 ms
# Epoch 102
# Training loss: 0.00094
# Validation loss: 0.00104
# Average inference time: 6.751 ms
# Epoch 103
# Training loss: 0.00035
# Validation loss: 0.00098
# Average inference time: 4.971 ms
# Epoch 104
# Training loss: 0.00031
# Validation loss: 0.01309
# Average inference time: 4.821 ms
# Epoch 105
# Training loss: 0.00033
# Validation loss: 0.00144
# Average inference time: 5.118 ms
# Epoch 106
# Training loss: 0.00024
# Validation loss: 0.00124
# Average inference time: 4.718 ms
# Epoch 107
# Training loss: 0.00021
# Validation loss: 0.00118
# Average inference time: 5.074 ms
# Epoch 108
# Training loss: 0.00020
# Validation loss: 0.00144
# Average inference time: 4.915 ms
# Epoch 109
# Training loss: 0.00019
# Validation loss: 0.00125
# Average inference time: 4.687 ms
# Epoch 110
# Training loss: 0.00018
# Validation loss: 0.00126
# Average inference time: 4.813 ms
# Epoch 111
# Training loss: 0.00018
# Validation loss: 0.00156
# Average inference time: 4.614 ms
# Epoch 112
# Training loss: 0.00017
# Validation loss: 0.00126
# Average inference time: 4.835 ms
# Epoch 113
# Training loss: 0.00016
# Validation loss: 0.00130
# Average inference time: 4.701 ms
# Epoch 114
# Training loss: 0.00018
# Validation loss: 0.00149
# Average inference time: 5.013 ms
# Epoch 115
# Training loss: 0.00021
# Validation loss: 0.00133
# Average inference time: 4.791 ms
# Epoch 116
# Training loss: 0.00017
# Validation loss: 0.00124
# Average inference time: 4.808 ms
# Epoch 117
# Training loss: 0.00016
# Validation loss: 0.00165
# Average inference time: 4.790 ms
# Epoch 118
# Training loss: 0.00016
# Validation loss: 0.00132
# Average inference time: 4.996 ms
# Epoch 119
# Training loss: 0.00017
# Validation loss: 0.00140
# Average inference time: 4.606 ms
# Epoch 120
# Training loss: 0.00015
# Validation loss: 0.00137
# Average inference time: 4.798 ms
# Epoch 121
# Training loss: 0.00015
# Validation loss: 0.00169
# Average inference time: 4.772 ms
# Epoch 122
# Training loss: 0.00015
# Validation loss: 0.00147
# Average inference time: 4.695 ms
# Epoch 123
# Training loss: 0.00015
# Validation loss: 0.00147
# Average inference time: 4.867 ms
# Epoch 124
# Training loss: 0.00015
# Validation loss: 0.00175
# Average inference time: 4.515 ms
# Epoch 125
# Training loss: 0.00015
# Validation loss: 0.00126
# Average inference time: 4.601 ms
# Epoch 126
# Training loss: 0.00016
# Validation loss: 0.00144
# Average inference time: 4.757 ms
# Epoch 127
# Training loss: 0.00016
# Validation loss: 0.00132
# Average inference time: 4.675 ms
# Epoch 128
# Training loss: 0.00014
# Validation loss: 0.00158
# Average inference time: 4.892 ms
# Epoch 129
# Training loss: 0.00015
# Validation loss: 0.00138
# Average inference time: 4.656 ms
# Epoch 130
# Training loss: 0.00018
# Validation loss: 0.00121
# Average inference time: 4.629 ms
# Epoch 131
# Training loss: 0.00015
# Validation loss: 0.00129
# Average inference time: 4.751 ms
# Epoch 132
# Training loss: 0.00014
# Validation loss: 0.00158
# Average inference time: 4.792 ms
# Epoch 133
# Training loss: 0.00014
# Validation loss: 0.00189
# Average inference time: 4.668 ms
# Epoch 134
# Training loss: 0.00014
# Validation loss: 0.00157
# Average inference time: 4.620 ms
# Epoch 135
# Training loss: 0.00015
# Validation loss: 0.00158
# Average inference time: 4.834 ms
# Epoch 136
# Training loss: 0.00014
# Validation loss: 0.00158
# Average inference time: 4.869 ms
# Epoch 137
# Training loss: 0.00014
# Validation loss: 0.00154
# Average inference time: 4.703 ms
# Epoch 138
# Training loss: 0.00014
# Validation loss: 0.00137
# Average inference time: 4.706 ms
# Epoch 139
# Training loss: 0.00014
# Validation loss: 0.00192
# Average inference time: 4.726 ms
# Epoch 140
# Training loss: 0.00072
# Validation loss: 0.00462
# Average inference time: 4.536 ms
# Epoch 141
# Training loss: 0.00059
# Validation loss: 0.00212
# Average inference time: 4.700 ms
# Epoch 142
# Training loss: 0.00036
# Validation loss: 0.00113
# Average inference time: 4.671 ms
# Epoch 143
# Training loss: 0.00026
# Validation loss: 0.00137
# Average inference time: 4.633 ms
# Epoch 144
# Training loss: 0.00031
# Validation loss: 0.00111
# Average inference time: 4.725 ms
# Epoch 145
# Training loss: 0.00025
# Validation loss: 0.00125
# Average inference time: 4.883 ms
# Epoch 146
# Training loss: 0.00023
# Validation loss: 0.00121
# Average inference time: 4.798 ms
# Epoch 147
# Training loss: 0.00018
# Validation loss: 0.00132
# Average inference time: 4.613 ms
# Epoch 148
# Training loss: 0.00016
# Validation loss: 0.00136
# Average inference time: 4.530 ms
# Epoch 149
# Training loss: 0.00016
# Validation loss: 0.00130
# Average inference time: 4.730 ms
# Epoch 150
# Training loss: 0.00015
# Validation loss: 0.00154
# Average inference time: 4.643 ms
# Epoch 151
# Training loss: 0.00015
# Validation loss: 0.00147
# Average inference time: 4.674 ms
# Epoch 152
# Training loss: 0.00015
# Validation loss: 0.00152
# Average inference time: 4.590 ms
# Epoch 153
# Training loss: 0.00014
# Validation loss: 0.00128
# Average inference time: 4.807 ms
# Epoch 154
# Training loss: 0.00014
# Validation loss: 0.00135
# Average inference time: 4.782 ms
# Epoch 155
# Training loss: 0.00013
# Validation loss: 0.00161
# Average inference time: 4.644 ms
# Epoch 156
# Training loss: 0.00013
# Validation loss: 0.00160
# Average inference time: 4.904 ms
# Epoch 157
# Training loss: 0.00013
# Validation loss: 0.00159
# Average inference time: 4.639 ms
# Epoch 158
# Training loss: 0.00013
# Validation loss: 0.00142
# Average inference time: 4.985 ms
# Epoch 159
# Training loss: 0.00013
# Validation loss: 0.00155
# Average inference time: 5.205 ms
# Epoch 160
# Training loss: 0.00014
# Validation loss: 0.00149
# Average inference time: 5.175 ms
# Epoch 161
# Training loss: 0.00024
# Validation loss: 0.00134
# Average inference time: 4.962 ms
# Epoch 162
# Training loss: 0.00016
# Validation loss: 0.00160
# Average inference time: 4.797 ms
# Epoch 163
# Training loss: 0.00014
# Validation loss: 0.00162
# Average inference time: 4.719 ms
# Epoch 164
# Training loss: 0.00013
# Validation loss: 0.00159
# Average inference time: 4.816 ms
# Epoch 165
# Training loss: 0.00013
# Validation loss: 0.00147
# Average inference time: 4.748 ms
# Epoch 166
# Training loss: 0.00013
# Validation loss: 0.00167
# Average inference time: 4.803 ms
# Epoch 167
# Training loss: 0.00012
# Validation loss: 0.00167
# Average inference time: 4.818 ms
# Epoch 168
# Training loss: 0.00012
# Validation loss: 0.00162
# Average inference time: 4.862 ms
# Epoch 169
# Training loss: 0.00012
# Validation loss: 0.00196
# Average inference time: 4.627 ms
# Epoch 170
# Training loss: 0.00013
# Validation loss: 0.00146
# Average inference time: 4.879 ms
# Epoch 171
# Training loss: 0.00058
# Validation loss: 0.01060
# Average inference time: 4.571 ms
# Epoch 172
# Training loss: 0.00047
# Validation loss: 0.00093
# Average inference time: 4.707 ms
# Epoch 173
# Training loss: 0.00035
# Validation loss: 0.00126
# Average inference time: 4.879 ms
# Epoch 174
# Training loss: 0.00023
# Validation loss: 0.00128
# Average inference time: 4.722 ms
# Epoch 175
# Training loss: 0.00024
# Validation loss: 0.00112
# Average inference time: 4.763 ms
# Epoch 176
# Training loss: 0.00024
# Validation loss: 0.00273
# Average inference time: 4.935 ms
# Epoch 177
# Training loss: 0.00019
# Validation loss: 0.00138
# Average inference time: 4.536 ms
# Epoch 178
# Training loss: 0.00015
# Validation loss: 0.00133
# Average inference time: 4.554 ms
# Epoch 179
# Training loss: 0.00015
# Validation loss: 0.00130
# Average inference time: 4.763 ms
# Epoch 180
# Training loss: 0.00014
# Validation loss: 0.00155
# Average inference time: 4.748 ms
# Epoch 181
# Training loss: 0.00014
# Validation loss: 0.00145
# Average inference time: 5.230 ms
# Epoch 182
# Training loss: 0.00013
# Validation loss: 0.00159
# Average inference time: 4.739 ms
# Epoch 183
# Training loss: 0.00013
# Validation loss: 0.00164
# Average inference time: 4.529 ms
# Epoch 184
# Training loss: 0.00013
# Validation loss: 0.00150
# Average inference time: 4.764 ms
# Epoch 185
# Training loss: 0.00012
# Validation loss: 0.00183
# Average inference time: 4.655 ms
# Epoch 186
# Training loss: 0.00013
# Validation loss: 0.00167
# Average inference time: 4.954 ms
# Epoch 187
# Training loss: 0.00012
# Validation loss: 0.00160
# Average inference time: 4.661 ms
# Epoch 188
# Training loss: 0.00012
# Validation loss: 0.00186
# Average inference time: 4.917 ms
# Epoch 189
# Training loss: 0.00011
# Validation loss: 0.00184
# Average inference time: 4.565 ms
# Epoch 190
# Training loss: 0.00012
# Validation loss: 0.00179
# Average inference time: 4.516 ms
# Epoch 191
# Training loss: 0.00012
# Validation loss: 0.00174
# Average inference time: 4.796 ms
# Epoch 192
# Training loss: 0.00012
# Validation loss: 0.00171
# Average inference time: 4.786 ms
# Epoch 193
# Training loss: 0.00012
# Validation loss: 0.00190
# Average inference time: 4.896 ms
# Epoch 194
# Training loss: 0.00011
# Validation loss: 0.00196
# Average inference time: 4.766 ms
# Epoch 195
# Training loss: 0.00011
# Validation loss: 0.00177
# Average inference time: 4.741 ms
# Epoch 196
# Training loss: 0.00012
# Validation loss: 0.00157
# Average inference time: 4.666 ms
# Epoch 197
# Training loss: 0.00011
# Validation loss: 0.00191
# Average inference time: 5.019 ms
# Epoch 198
# Training loss: 0.00011
# Validation loss: 0.00180
# Average inference time: 5.262 ms
# Epoch 199
# Training loss: 0.00011
# Validation loss: 0.00200
# Average inference time: 4.674 ms
# Epoch 200
# Training loss: 0.00011
# Validation loss: 0.00182
# Average inference time: 4.802 ms

# %%
# Load saved weights
model.load_state_dict(torch.load(model_path))
avg_loss, avg_time = evaluate(model, device, valloader, criterion)
avg_loss, avg_time
# Out:
# Validation loss: 0.00091
# Average inference time: 4.916 ms
# (0.0009105204666654268, 4.91641362508138)

# %%
# So we have a history of results
import pandas as pd
import datetime
try:
  df = pd.read_csv('summary.csv', index_col=0)
except FileNotFoundError:
  df = pd.DataFrame(columns=['model name', 'date', 'num flops', 'num params', 'best val train loss', 'best val loss', 'colab inference time (ms)'])
row = {
    'model name': model_name,
    'date': datetime.datetime.now(),
    'num flops': flops,
    'num params': params,
    'best val loss': best_loss,
    'colab inference time (ms)': avg_time,
}
df = df.append(row, ignore_index=True)
df.to_csv('summary.csv')
df
# Out:
#        model name                        date  ...  +3x3 asm  +unroll asm
# 0   NeuralNetwork  2020-05-30 16:50:11.531938  ...  0.045973     0.039756
# 1            JNN1  2020-05-31 07:42:00.238484  ...  0.043682     0.037389
# 2            JNN2  2020-05-31 09:07:49.131277  ...  0.044441     0.038354
# 3            JNN3  2020-05-31 12:00:21.437022  ...  0.035248     0.029669
# 4            JNN4  2020-05-31 13:04:46.042455  ...  0.041215     0.037312
# 5            JNN5  2020-05-31 14:14:21.150786  ...  0.037959     0.034760
# 6            JNN6  2020-05-31 15:22:09.758481  ...  0.032465     0.028794
# 7            JNN7  2020-05-31 17:20:45.904784  ...  0.025932     0.022551
# 8            JNN8  2020-05-31 18:23:37.926662  ...  0.028161     0.024581
# 9            JNN9  2020-06-01 03:55:24.764050  ...  0.039478     0.034086
# 10          JNN10  2020-06-01 07:09:51.942441  ...  0.054968     0.049369
# 11          JNN11  2020-06-01 08:49:55.855645  ...  0.072963     0.065335
# 12          JNN12  2020-06-11 06:35:37.955403  ...       NaN          NaN
# 13          JNN13  2020-06-11 08:02:28.854583  ...       NaN          NaN
# 14          JNN16  2020-06-11 10:45:11.239928  ...       NaN          NaN
# 15          JNN18  2020-06-11 13:04:04.794637  ...       NaN          NaN
# 16          JNN19  2020-06-11 15:19:13.700506  ...       NaN          NaN
#
# [17 rows x 14 columns]

# %%
# Display and save results
display_results(model, device, valloader, thresh=0.5, save_dst=None)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
